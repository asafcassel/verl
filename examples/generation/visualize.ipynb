# %%
import pandas as pd
import os

home = os.path.expanduser("~")
group_idx = 4
group_range = f"{group_idx *10}-{(group_idx + 1) * 10}"

src_data_path = f"{home}/data/deepscaler_percentiles/test_percentiles_{group_range}.parquet"
data_path_0 = f"{home}/data/deepscaler_percentiles_responses/ckpt_step_0/test_percentiles_{group_range}.parquet"
data_path_1704 = f"{home}/data/deepscaler_percentiles_responses/ckpt_step_1704/test_percentiles_{group_range}.parquet"

dataset_0 = pd.read_parquet(data_path_0)
dataset_1704 = pd.read_parquet(data_path_1704)
src_dataset = pd.read_parquet(src_data_path)

# %%
i = 201
clip = 50

print(f"{i}/{dataset_0['prompt'].size}")
print(f"Q: {dataset_0['prompt'][i][0]['content']}")
print(f"A: {src_dataset['reward_model'][i]['ground_truth']}")
print(f"Pred: {dataset_0['responses'][i][0][-clip:]}")
print(f"Pred: {dataset_1704['responses'][i][0][-clip:]}")
# Out:
# 201/403
# Q: Eight students from a university are preparing to carpool for a trip. There are two students from each grade level—freshmen, sophomores, juniors, and seniors—divided into two cars, Car A and Car B, with each car seating four students. The seating arrangement of the four students in the same car is not considered. However, the twin sisters, who are freshmen, must ride in the same car. The number of ways for Car A to have exactly two students from the same grade is _______. Let's think step by step and output the final answer within \boxed{}.
# A: 24
# Pred: First, let's break down the problem. We have eight students from four grade levels: freshmen, sophomores, juniors, and seniors. There are two students from each grade level. The twin sisters, who are freshmen, must ride in the same car. We need to find the number of ways for Car A to have exactly two students from the same grade.
#
# 1. **Identify the possible scenarios for Car A:**
# ...
